# %%
from wxpy import *
# 初始化机器人，扫码登陆
bot = Bot()
my_friend = bot.friends()
my_groups = bot.groups()


#ywwlcn
#e7f5dd99
# Out:
# █
# Getting uuid of QR code.
# Downloading QR code.
# Please scan the QR code to log in.
# Please press confirm on your phone.
# Loading the contact, this may take a little while.
# Login successfully as EvilPsyCHo

# %%
import wxpy

# %%
my_friend = bot.friends()
my_groups = bot.groups()

# %%
@bot.register(my_friend)
def reply_my_friend(msg):
#     print(type(msg.text))
#     return '正在测试chatbot\n输入文本:{}\n输入类型:{}\n对话id:{}\n昵称:{}'.format(
#         msg.text,
#         msg.type,
#         msg.id,
#         msg.sender.remark_name,

#     )
    pass
# Out:
# ['@周知瑞', '打招呼', 'hello']
# 王俊程 打招呼 hello
#
# ['@周知瑞', '打招呼', '今天天气不错哦']
# 稍。 打招呼 今天天气不错哦
#
# ['@周知瑞', '表扬', '你们公司真是高大上']
# 王俊程 表扬 你们公司真是高大上
#
# ['@周知瑞', '', '', '文件检索', '储能政策']
# ['@周知瑞', '打招呼', '您吃了吗？']
# 令狐 打招呼 您吃了吗？
#
# ['@周知瑞', '文件检索', '储能政策']
# jqLi 文件检索 储能政策
#
# ['@周知瑞', '打招呼', '走，吃火锅去。']
# 令狐 打招呼 走，吃火锅去。

# %%
@bot.register(my_groups)
def reply_my_group(msg):
    if msg.is_at:
        if "提示" in msg.text:
            return """你好，chatbot需要你的帮助，优化意图识别模型\n
            目前支持需要完善的意图有：公司咨询（地址联系方式等）、业务咨询（产品、业务范围）、数据查询（用电数据）、文件检索（政策文件）。\n
            例子：\n
            @周知瑞 公司咨询 你们公司地址在哪？\n
            @周知瑞 业务咨询 你们有什么服务\n
            @周知瑞 数据查询 上个星期3到星期2，来福士空调用了多少电？\n
            @周知瑞 文件检索 最近一个月四川能监办，跨省跨区文件\n
            """
        else:
#             print(msg.text.split(" "))
            flag = insert(msg.text, msg.member.name)
            if flag is True:
                return "谢谢{},成功添加一条意图识别样本".format(msg.member.name)
            else:
                return "您提供的样本格式有些问题哦，具体情况请输入“@周知瑞 提示”"

# %%
import re
def insert(text, name):
    path = "/home/zhouzr/project/Task-Oriented-Chatbot/corpus/intent_corpus.txt"
    text=text.replace("\u2005", " ")
    text=text.replace("  ", " ")
    print(text.split(" "))
    t = text.split(" ")
    flag = False
    if len(t) == 3:
        with open(path, 'a') as f:
            s = " ".join([name, t[1], t[2], "\n"])
            print(s)
            f.write(s)
            flag=True
    return flag
# Out:
# ['@周知瑞', '数据查询', '来福士最近一周峰期用电占比']
# jqLi 数据查询 来福士最近一周峰期用电占比
#
# ['@周知瑞', '再见', '回见了您嘞']
# 令狐 再见 回见了您嘞
#
# ['@周知瑞', '表扬', '令狐减肥五斤成功，举公司欢庆']
# 稍。 表扬 令狐减肥五斤成功，举公司欢庆
#
# ['@周知瑞', '数据查询', '长江机械电压等级']
# jqLi 数据查询 长江机械电压等级
#
# ['@周知瑞', '数据查询', '我们公司这个月平均电量多少？']
# 令狐 数据查询 我们公司这个月平均电量多少？
#
# ['@周知瑞', '数据查询', '小益，帮我查下这个月最大电量。']
# 令狐 数据查询 小益，帮我查下这个月最大电量。
#
# ['@周知瑞', '留言', '请你们业务经理给我联系！']
# 令狐 留言 请你们业务经理给我联系！
#
# ['@周知瑞', '数据查询', '查一下采集设备个数']
# jqLi 数据查询 查一下采集设备个数
#
# ['@周知瑞', '数据查询', '近一月单耗查询']
# jqLi 数据查询 近一月单耗查询
#
# ['@周知瑞', '数据查询', '小益，看看高配温度多高？空调启动没？']
# 令狐 数据查询 小益，看看高配温度多高？空调启动没？
#
# ['@周知瑞', '万益能源科技有限公司介绍']
# ['@周知瑞', '数据查询', '这个月电费多少']
# 令狐 数据查询 这个月电费多少
#
# ['', '@周知瑞', '数据查询', '令狐这个月用了多少电']
# ['', '@周知瑞', '数据查询', '我这个月用了多少电']
# ['', '@周知瑞', '数据查询', '令狐这个月用了多少电']
# ['', '@周知瑞', '数据查询', '令狐这个月用了多少电']
# ['@周知瑞', '数据查询', '我这个月用了多少电']
# 幸福在明天 数据查询 我这个月用了多少电
#
# ['@周知瑞', '数据查询', '华宇这个月用了多少电']
# 幸福在明天 数据查询 华宇这个月用了多少电
#
# ['@周知瑞', '数据查询', '他这个月用了多少电']
# 幸福在明天 数据查询 他这个月用了多少电
#
# ['@周知瑞', '数据查询', '我这个月电梯用了多少电']
# 幸福在明天 数据查询 我这个月电梯用了多少电
#
# ['@周知瑞', '数据查询', '来福士空调开的几度']
# 幸福在明天 数据查询 来福士空调开的几度
#
# ['@周知瑞', '打招呼', '萨瓦迪卡！']
# 令狐 打招呼 萨瓦迪卡！
#
# ['@周知瑞', '打招呼', 'hi']
# 令狐 打招呼 hi
#
# ['@周知瑞', '数据查询', '这个月电费咋这么多[机智][机智][机智][机智][皱眉]']
# 幸福在明天 数据查询 这个月电费咋这么多[机智][机智][机智][机智][皱眉]
#
# ['@周知瑞', '表扬', '你怎么这么牛逼呢']
# syl 表扬 你怎么这么牛逼呢
#
# ['@周知瑞', '文件检索', '今年5月的月度交易公告']
# 幸福在明天 文件检索 今年5月的月度交易公告
#
# ['@周知瑞', '打招呼', '[勾引][勾引]']
# 令狐 打招呼 [勾引][勾引]
#
# ['@周知瑞', '公司咨询', '公司的主要业务']
# syl 公司咨询 公司的主要业务
#
# ['@周知瑞', '否定', '数据错了！！']
# 令狐 否定 数据错了！！
#
# ['@周知瑞', '否定', '怎么搞的啊']
# 令狐 否定 怎么搞的啊
#
# ['@周知瑞', '肯定', '方案不错！']
# 令狐 肯定 方案不错！
#
# ['@周知瑞', '肯定', '价格很实在']
# 令狐 肯定 价格很实在
#
# ['@周知瑞', '数据查询', '今年计划电量是多少']
# 幸福在明天 数据查询 今年计划电量是多少
#
# ['@周知瑞', '数据查询', '华宇计划电量咋分配的']
# 幸福在明天 数据查询 华宇计划电量咋分配的
#
# ['@周知瑞', '数据查询', '偏差预估？']
# 李家强 数据查询 偏差预估？
#
# ['@周知瑞', '数据查询', '这个月😫', '买了好多电']
# ['@周知瑞', '数据查询', '我😀', '这个月用了多少电m9(´∀｀)就是你！']
# ['@周知瑞', '数据查询', '我这个月用了多少电🙂', '']
# ['@周知瑞', '数据查询', '我这个月用了多少电']
# 幸福在明天 数据查询 我这个月用了多少电
#
# ['@周知瑞', '打招呼', '你莫得表情包']
# 幸福在明天 打招呼 你莫得表情包
#
# ['@周知瑞', '这个要科普一下，没懂[呲牙]']
# ['@周知瑞', '公司咨询，智能运维的优势']
# ['@周知瑞', '公司咨询', '智能运维的优势']
# 令狐 公司咨询 智能运维的优势
#
# ['@周知瑞', '公司咨询', '智能运维的优势']
# 杨总杨淮年 公司咨询 智能运维的优势
#
# ['@周知瑞', '政策_文件检索', '四川省结算电价有哪些品类']
# 憨笑米兔 政策_文件检索 四川省结算电价有哪些品类
#
# ['@周知瑞', '文件检索', '四川结算规则文件']
# 郭超 文件检索 四川结算规则文件
#
# ['@周知瑞', '政策_文件检索', '商业电价和居民电价有啥区别。']
# 令狐 政策_文件检索 商业电价和居民电价有啥区别。
#
# ['@周知瑞', '业务咨询', '最近供电设备运行状态如何？']
# 迟景华 业务咨询 最近供电设备运行状态如何？
#
# ['@周知瑞', '四川省能源办', '电力安全生产年。']
# 一笑而过 四川省能源办 电力安全生产年。
#
# ['@周知瑞', '业务咨询', '年检预试怎么收费']
# 陈德靖 业务咨询 年检预试怎么收费
#
# ['@周知瑞', '业务咨询', '电缆调试做吗？']
# 令狐 业务咨询 电缆调试做吗？
#
# ['@周知瑞', '业务咨询', '变电站运行多少钱？']
# 令狐 业务咨询 变电站运行多少钱？
#
# ['@周知瑞', '业务咨询', '业务有生命周期管理吗？']
# 李家强 业务咨询 业务有生命周期管理吗？
#
# ['@周知瑞', '公司咨询', '抢修工作哪个部门在负责']
# 陈德靖 公司咨询 抢修工作哪个部门在负责
#
# ['@周知瑞', '业务咨询', '变电站运行多少钱？']
# 令狐 业务咨询 变电站运行多少钱？
#
# ['@周知瑞', '闲聊', '好久可以组织活动啊']
# 令狐 闲聊 好久可以组织活动啊
#
# ['@周知瑞', '闲聊', '世界杯开始了去约酒哇[偷笑]']
# 令狐 闲聊 世界杯开始了去约酒哇[偷笑]
#
# ['@周知瑞', '闲聊', '甲米热不热？']
# 陈德靖 闲聊 甲米热不热？
#
# ['@周知瑞', '闲聊', '好久去踢球哇？']
# 令狐 闲聊 好久去踢球哇？
#
# ['@周知瑞', '业务咨询', '可以安装充电桩吗']
# 陈德靖 业务咨询 可以安装充电桩吗
#
# ['@周知瑞', '业务咨询', '可以做储能电池吗']
# 令狐 业务咨询 可以做储能电池吗
#
# ['@周知瑞', '业务咨询', '储能电池的品牌有哪些']
# 陈德靖 业务咨询 储能电池的品牌有哪些
#
# ['@周知瑞', '文件检索', '华宇电力安全年活动']
# 陈德靖 文件检索 华宇电力安全年活动
#
# ['@周知瑞', '闲聊', 'JR今天是不是买了勇士赢']
# 陈德靖 闲聊 JR今天是不是买了勇士赢
#
# ['@周知瑞', '闲聊', '曼联是冠军']
# ONE PUNCH MAN 闲聊 曼联是冠军
#
# ['@周知瑞', '文件检索', '国家能源局安全年']
# 陈德靖 文件检索 国家能源局安全年
#
# ['@周知瑞', '闲聊', '齐达内为什么叫齐祖']
# 陈德靖 闲聊 齐达内为什么叫齐祖
#
# ['@周知瑞', '闲聊', '马特拉奇对齐达内说了什么']
# 陈德靖 闲聊 马特拉奇对齐达内说了什么
#
# ['@周知瑞', '闲聊', '齐达内会来中超吗']
# 陈德靖 闲聊 齐达内会来中超吗
#
# ['@周知瑞', '表扬', '队长好棒！']
# 令狐 表扬 队长好棒！
#
# ['@周知瑞', '表扬', '令狐做菜太好吃了']
# 陈德靖 表扬 令狐做菜太好吃了
#
# ['@周知瑞', '表扬', '想念玄哥']
# 陈德靖 表扬 想念玄哥
#
# ['@周知瑞', '旅游', '多带点中国烟[悠闲]']
# 一笑而过 旅游 多带点中国烟[悠闲]
#
# ['@周知瑞', '业务咨询', '参与市场购电有什么风险']
# RumblinWreck 业务咨询 参与市场购电有什么风险
#
# ['@周知瑞', '业务咨询', '地铁可以到你们公司吗？开车怎么停车？']
# 令狐 业务咨询 地铁可以到你们公司吗？开车怎么停车？
# LOG OUT!

# %%
my_groups
# Out:
# [<Group: 周家大院亲友团大家庭>,
#  <Group: PE/VC/并购群>,
#  <Group: 万益能源研发团队>,
#  <Group: 华宇&amp;万益2018年度旅游>,
#  <Group: 无领导群>,
#  <Group: [BigQuant]人工智能量化交易3>,
#  <Group: chatbot养育中心>,
#  <Group: 女大学生天团_王者荣耀总部>,
#  <Group: 负荷预测无领导>]
